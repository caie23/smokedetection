# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8.yaml')  # build a model from scratch

# Train the model
model.train(task='detect', mode='train', data='smokedata/smoke.yaml', epochs=100, batch=16, name='v8_100e_16b')

# use the mode lto predict test data
results = model(source='smokedata/images/test/', save=True, save_txt=True)

# export model as onnx format
model.export(format='onnx')
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
from ultralytics import YOLO
# load the model
model = YOLO("v8best.pt")
# export model as onnx format
model.export(format='onnx', opset=12)
# Out:
# Ultralytics YOLOv8.0.119 🚀 Python-3.10.10 torch-1.12.1 CPU
# YOLOv8 summary (fused): 168 layers, 3005843 parameters, 0 gradients
#
# PyTorch: starting from v8best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.9 MB)
#
# ONNX: starting export with onnx 1.14.0 opset 12...
# ONNX: export success ✅ 2.3s, saved as v8best.onnx (11.7 MB)
#
# Export complete (3.0s)
# Results saved to /home/fengcg/notebooks
# Predict:         yolo predict task=detect model=v8best.onnx imgsz=640
# Validate:        yolo val task=detect model=v8best.onnx imgsz=640 data=smokedata/smoke.yaml
# Visualize:       https://netron.app
# 'v8best.onnx'

# %%
# load the model
model = YOLO("yolov8m.pt")
# export model as onnx format
model.export(format='onnx', opset=12)
# Out:
# Ultralytics YOLOv8.0.119 🚀 Python-3.10.10 torch-1.12.1 CPU
# YOLOv8m summary (fused): 218 layers, 25886080 parameters, 0 gradients
#
# PyTorch: starting from yolov8m.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (49.7 MB)
#
# ONNX: starting export with onnx 1.14.0 opset 12...
# ONNX: export success ✅ 5.1s, saved as yolov8m.onnx (98.9 MB)
#
# Export complete (5.8s)
# Results saved to /home/fengcg/notebooks
# Predict:         yolo predict task=detect model=yolov8m.onnx imgsz=640
# Validate:        yolo val task=detect model=yolov8m.onnx imgsz=640 data=coco.yaml
# Visualize:       https://netron.app
# 'yolov8m.onnx'

# %%
model = YOLO("v8best.pt")
results1 = model(source='fightdata/fight/', save=True, save_txt=True)
results2 = model(source='fightdata/noFight/', save=True, save_txt=True)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/150 (1/53) /home/fengcg/notebooks/fightdata/fight/fi001.mp4: 480x640 (no detections), 43.5ms
# video 1/150 (2/53) /home/fengcg/notebooks/fightdata/fight/fi001.mp4: 480x640 (no detections), 35.9ms
# video 1/150 (3/53) /home/fengcg/notebooks/fightdata/fight/fi001.mp4: 480x640 (no detections), 30.0ms
# video 1/150 (4/53) /home/fengcg/notebooks/fightdata/fight/fi001.mp4: 480x640 (no detections), 29.8ms
# ...
